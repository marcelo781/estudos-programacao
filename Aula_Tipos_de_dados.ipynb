# %% [markdown]
# <a href="https://colab.research.google.com/github/marcelo781/estudos-programacao/blob/main/Aula_Tipos_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Descobrir tipo de variável
type(nome)

# %%
a = 100
b = 25.6
c = a == b 
d = "Sim"

# %%
print(c)
# Out:
# False

# %%
type (d)
# Out:
# str

# %% [markdown]
# Tipos de dados booleanos

# %%
a = 100 < 200
b = 85 == 6
c = "Marcelo" == "Marcelo"
d = 25 == "25"
e = 30 == (6*5)
f = "Vasco" > "Flamengo"

# %%
print (a)
print (b)
print (c)
print (d)
print (e)
print (f)
# Out:
# True
# False
# True
# False
# True
# True

# %%
notaAprovacao = 7.0
notaWalison = 5.0
print(notaAprovacao < notaWalison)
# Out:
# False

# %%
if (notaWalison >= notaAprovacao):
  print("Aprovado")
else: 
  print("Reprovado")
# Out:
# Reprovado

# %%
type (c)
# Out:
# bool

# %%
type (a)
# Out:
# int

# %%
type (b)
# Out:
# float

# %%
print('My first notebook')
nome = 'Marcelo'
print(nome)
# Out:
# My first notebook
# Marcelo

# %%
notaMarcelo = 1
if(notaMarcelo >= 7.0):
  print("Aprovado")
elif(notaMarcelo >= 4 and notaMarcelo < 7):
  print("Recuperação")
else:
  print("Reprovado")
# Out:
# Reprovado

# %%
if(notaMarcelo <4):
  print("Reprovado")
elif(notaMarcelo < 7):
  print("Recuperação")
else:
  print("Aprovado")
# Out:
# Reprovado

# %% [markdown]
# Input de Dados no Python

# %%
nota = input("Digite a nota, pae!")
print(nota)
# Out:
# Digite a nota, pae!8
# 8

# %%
#O velho e bom PARSE

nota1 = float(input("Digite a nota, pae!"))
nota2 = float(input("Digite segunda nota!"))
print(nota1+nota2)
# Out:
# Digite a nota, pae!10
# Digite segunda nota!10
# 20.0

# %%
nota1 = float(input("Digite a nota"))
nota2 = float(input("Digite a segunda nota"))
nota3 = float(input("Digite a terceira nota"))
media = (nota1+nota2+nota3)/3
print(media)
# Out:
# Digite a nota10
# Digite a segunda nota7
# Digite a terceira nota8
# 8.333333333333334
